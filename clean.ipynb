# %%
# Import the relevent packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /Users/olingilster/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df = pd.read_excel('data.xlsx', sheet_name='AMX_DONATION_LINES')
df2 = pd.read_excel('data.xlsx', sheet_name='AMX_DONATION_HEADER')
df.head()
# Out:
#   DONATIONNUMBER ITEMNUMBER  \
# 0     WD24090290      35031
# 1     WD24090279     373180
# 2     WD24090279     373182
# 3     WD24090279     411718
# 4     WD24090279     243800
#
#                                      ITEMDESCRIPTION   DONATIONREASON  PACK  \
# 0  Penne pasta in a Creamy Alfredo Sauce with Chi...  Quality Control   6.0
# 1            GOLD PEAK RSPBRYTEA 52OZ(1.53L)PLBT1LS6       CLOSE CODE   6.0
# 2                GOLD PEAK PEACH 52OZ(1.53L)PLBT1LS6       CLOSE CODE   6.0
# 3           Minute Maid Habiscus 52OZ(1.53L)PLBT1LS6       CLOSE CODE   NaN
# 4              MINUTE MAID OJ 100+CAL CHL 59OZ  1LS8       CLOSE CODE   8.0
#
#    SIZE_ SIZEUOM   PACKAGINGTYPE UNITOFMEASURE  QUANTITY  ...  \
# 0   10.0   Ounce           Other          Case      2129  ...
# 1   52.0   Ounce  Plastic Bottle          Case       252  ...
# 2   52.0   Ounce  Plastic Bottle          Case        54  ...
# 3    NaN     NaN           Other          Case        90  ...
# ...

# %%
print(df.columns.tolist())
# Out:
# ['DONATIONNUMBER', 'ITEMNUMBER', 'ITEMDESCRIPTION', 'DONATIONREASON', 'PACK', 'SIZE_', 'SIZEUOM', 'PACKAGINGTYPE', 'UNITOFMEASURE', 'QUANTITY', 'QUANTITYPERPALLET', 'TOTALPALLETS', 'GROSSWEIGHT', 'TOTALGROSSWEIGHT', 'NETWEIGHT', 'CUBE', 'STORAGEREQUIREMENT', 'MANUFACTUREDATE', 'EXPIRATIONDATE', 'SHELFLIFE', 'EXTENSION', 'USEBYDATE', 'BILLOFLADINGNUMBER', 'STATUS', 'CODEDATETYPE', 'MAGREFNUMBER']

# %%
null_counts = df.isnull().sum()
df.columns = df.columns.str.strip()
print(null_counts)
# Out:
# DONATIONNUMBER           0
# ITEMNUMBER               0
# ITEMDESCRIPTION          0
# DONATIONREASON           3
# PACK                  2352
# SIZE_                 2782
# SIZEUOM               3093
# PACKAGINGTYPE           10
# UNITOFMEASURE           10
# QUANTITY                 0
# QUANTITYPERPALLET        0
# TOTALPALLETS             0
# GROSSWEIGHT              0
# TOTALGROSSWEIGHT         0
# NETWEIGHT             2000
# CUBE                  7406
# STORAGEREQUIREMENT       0
# MANUFACTUREDATE       5494
# EXPIRATIONDATE        2216
# SHELFLIFE             3249
# EXTENSION             1005
# USEBYDATE              228
# BILLOFLADINGNUMBER    4660
# STATUS                  68
# CODEDATETYPE          7406
# MAGREFNUMBER             0
# dtype: int64

# %%
# dropping specific values in the dataset

null_percentage = df.isnull().mean() * 100

columns_to_drop = null_percentage[null_percentage > 70].index

df = df.drop(columns=columns_to_drop)

print("Dropped columns:", list(columns_to_drop))
df.head(10)
# Out:
# Dropped columns: ['CUBE', 'MANUFACTUREDATE', 'CODEDATETYPE']
#   DONATIONNUMBER  ITEMNUMBER  \
# 0     WD24090290       35031
# 1     WD24090279      373180
# 2     WD24090279      373182
# 3     WD24090279      411718
# 4     WD24090279      243800
# 5     WD24090279      243782
# 6     WD24090266  7495619304
# 7     WD24090261  1000007473
# 8     WD24090261    MCF03783
# 9     WD24090261   OIF00024A
#
#                                      ITEMDESCRIPTION   DONATIONREASON  PACK  \
# 0  Penne pasta in a Creamy Alfredo Sauce with Chi...  Quality Control   6.0
# 1            GOLD PEAK RSPBRYTEA 52OZ(1.53L)PLBT1LS6       CLOSE CODE   6.0
# 2                GOLD PEAK PEACH 52OZ(1.53L)PLBT1LS6       CLOSE CODE   6.0
# 3           Minute Maid Habiscus 52OZ(1.53L)PLBT1LS6       CLOSE CODE   NaN
# 4              MINUTE MAID OJ 100+CAL CHL 59OZ  1LS8       CLOSE CODE   8.0
# 5    Bright and Early (NC) CHL 59OZ(1.75LT)FXCT 1LS8       CLOSE CODE   NaN
# ...

# %%
# dropping the billing number because it is not valuable
df = df.drop(columns='BILLOFLADINGNUMBER')

# %%
df2_filtered = df2[['DONATIONNUMBER', 'DONATIONDATE']]
unique_donations = df2_filtered['DONATIONNUMBER'].unique()
# unique_donations
unique_donations1 = df['DONATIONNUMBER'].unique()
# unique_donations1
overlap = np.intersect1d(unique_donations1, unique_donations)
overlap

df_joined = pd.merge(df, df2_filtered, on='DONATIONNUMBER', how='left')
df_joined
# Out:
#      DONATIONNUMBER    ITEMNUMBER  \
# 0        WD24090290         35031
# 1        WD24090279        373180
# 2        WD24090279        373182
# 3        WD24090279        411718
# 4        WD24090279        243800
# ...             ...           ...
# 7401     WD24080390  210000489800
# 7402     WD24080390  210000604900
# 7403     WD24080390  210000607000
# 7404     WD24080390  210000655300
# 7405     WD24080390  210000786100
#
#                                         ITEMDESCRIPTION   DONATIONREASON  \
# 0     Penne pasta in a Creamy Alfredo Sauce with Chi...  Quality Control
# 1               GOLD PEAK RSPBRYTEA 52OZ(1.53L)PLBT1LS6       CLOSE CODE
# 2                   GOLD PEAK PEACH 52OZ(1.53L)PLBT1LS6       CLOSE CODE
# 3              Minute Maid Habiscus 52OZ(1.53L)PLBT1LS6       CLOSE CODE
# 4                 MINUTE MAID OJ 100+CAL CHL 59OZ  1LS8       CLOSE CODE
# ...                                                 ...              ...
# ...

# %%
# Define our indepedent and dependent variables
independent_variables = ["DONATIONREASON", "SHELFLIFE", "PACKAGINGTYPE", "SIZE_", "SIZEUOM", "STORAGEREQUIREMENT", "PACK", "UNITOFMEASURE"]
dependent_variable = 
# experieation date - donatation date
